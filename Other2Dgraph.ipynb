# %%
from matplotlib import pylab
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
x = np.linspace(0, 10, 25)
y = x * x + 2
print(x)
print(y)
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]
# [  2.           2.17361111   2.69444444   3.5625       4.77777778
#    6.34027778   8.25        10.50694444  13.11111111  16.0625
#   19.36111111  23.00694444  27.          31.34027778  36.02777778
#   41.0625      46.44444444  52.17361111  58.25        64.67361111
#   71.44444444  78.5625      86.02777778  93.84027778 102.        ]

# %% [markdown]
# Other 2D Graphics

# %%
n = np.array([0,1,2,3,4,5])

fig, axes = plt.subplots(1, 4, figsize=(16,5))

# %%
n = np.array([0,1,2,3,4,5])

fig, axes = plt.subplots(1, 4, figsize=(16,5))
axes[0].set_title("scatter")
axes[0].scatter(x, x+0.25*np.random.randn(len(x)))

axes[1].set_title("step")
axes[1].step(n, n**2 , lw=2)

axes[2].set_title("bar")
axes[2].bar(n, n**2, align="center",width = 0.5, alpha= 0.5)

axes[3].set_title("fill")
axes[3].fill(x, x**2, x**3, color="green", alpha= 0.9)
# Out:
# [<matplotlib.patches.Polygon at 0x1da75f9d220>,
#  <matplotlib.patches.Polygon at 0x1da75f9d2e0>]

# %%
"""Draw a radar chart
"""
fig = plt.figure(figsize=(6,6))
ax = fig.add_axes([0.0, 0.0, .9, .9], polar=True)
t = np.linspace(0, 2 * np.pi, 100)
ax.plot(t, t*.5, color = 'blue', lw =3)

# %%
"""Draw histogram"""

n= np.random.randn(100000)
fig, axes = plt.subplots(1, 2, figsize=(12,6))

axes[0].set_title("Default histogram")
axes[0].hist(n)

axes[1].set_title("Cumulative detailed histogram")
axes[1].hist(n, cumulative =  True, bins=50)
# Out:
# (array([2.0000e+00, 3.0000e+00, 1.5000e+01, 3.1000e+01, 5.1000e+01,
#         1.0000e+02, 1.7200e+02, 3.0300e+02, 5.0300e+02, 8.1000e+02,
#         1.2270e+03, 1.9280e+03, 2.8670e+03, 4.2280e+03, 6.0130e+03,
#         8.3370e+03, 1.1346e+04, 1.4881e+04, 1.9053e+04, 2.4112e+04,
#         2.9633e+04, 3.5791e+04, 4.2328e+04, 4.8991e+04, 5.5591e+04,
#         6.2168e+04, 6.8528e+04, 7.4157e+04, 7.9363e+04, 8.3896e+04,
#         8.7724e+04, 9.0885e+04, 9.3373e+04, 9.5281e+04, 9.6729e+04,
#         9.7792e+04, 9.8545e+04, 9.9068e+04, 9.9426e+04, 9.9661e+04,
#         9.9791e+04, 9.9885e+04, 9.9942e+04, 9.9974e+04, 9.9982e+04,
#         9.9990e+04, 9.9996e+04, 9.9998e+04, 9.9999e+04, 1.0000e+05]),
#  array([-4.09847046, -3.92868611, -3.75890177, -3.58911742, -3.41933307,
#         -3.24954872, -3.07976438, -2.90998003, -2.74019568, -2.57041134,
#         -2.40062699, -2.23084264, -2.06105829, -1.89127395, -1.7214896 ,
#         -1.55170525, -1.38192091, -1.21213656, -1.04235221, -0.87256786,
#         -0.70278352, -0.53299917, -0.36321482, -0.19343048, -0.02364613,
#          0.14613822,  0.31592257,  0.48570691,  0.65549126,  0.82527561,
#          0.99505995,  1.1648443 ,  1.33462865,  1.504413  ,  1.67419734,
#          1.84398169,  2.01376604,  2.18355038,  2.35333473,  2.52311908,
#          2.69290342,  2.86268777,  3.03247212,  3.20225647,  3.37204081,
#          3.54182516,  3.71160951,  3.88139385,  4.0511782 ,  4.22096255,
#          4.3907469 ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# Draw Contour image

# %%
import matplotlib
import matplotlib.cm as cm
import matplotlib.pyplot as plt

delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X-1)**2 - (Y-1)**2)

Z = (Z1-Z2) *2

print(X)
print(Y)
# Out:
# [[-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  ...
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]]
# [[-2.    -2.    -2.    ... -2.    -2.    -2.   ]
#  [-1.975 -1.975 -1.975 ... -1.975 -1.975 -1.975]
#  [-1.95  -1.95  -1.95  ... -1.95  -1.95  -1.95 ]
#  ...
#  [ 1.925  1.925  1.925 ...  1.925  1.925  1.925]
#  [ 1.95   1.95   1.95  ...  1.95   1.95   1.95 ]
#  [ 1.975  1.975  1.975 ...  1.975  1.975  1.975]]
